# %% [markdown]
# # Diversity stats

# %%
# !pip install -q malariagen_data
# !pip install -q scikit-allel
# !pip install -q pomegranate
# Out:
#   Building wheel for pomegranate (pyproject.toml) ... done

# %% [markdown]
# ### importing necessary package

# %%
import allel
import malariagen_data
import numpy as np
import pandas as pd
import dask
import dask.array as da
# silence some dask warnings
dask.config.set(**{'array.slicing.split_large_chunks': True})
from dask.diagnostics.progress import ProgressBar

# %%
import random
import itertools
#import plotly
import plotly.express as px
#import plotly.io as pio
#import pomegranate

# %%
# plotting setup
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.gridspec import GridSpec
import matplotlib_venn as venn
import seaborn as sns

# %%
#Mounting Google Drive
import os
from google.colab import drive
drive.mount("drive")

# make dir
results_dir = "drive/MyDrive/Genomic/"
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# Importing malariagen data set

# %%
ag3 = malariagen_data.Ag3("gs://vo_agam_release/", pre=True)
#ag3

#samples sets
sets = ["1191-VO-MULTI-OLOUGHLIN-VMF00106", "1191-VO-MULTI-OLOUGHLIN-VMF00140",
        "AG1000G-BF-A", "AG1000G-BF-B", "AG1000G-BF-C"]
df_samples = ag3.sample_metadata(sample_sets=sets)#.set_index("sample_id")
bf_samples = df_samples.query('country == "Burkina Faso"')
# Out:
# Load sample metadata:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# # diversity stats in the 2R chrom

# %%
div_stats_2R = ag3.diversity_stats(sample_query="country == 'Burkina Faso'",
                                cohorts="admin2_year",
                                cohort_size=10,
                                region="2R",
                                site_mask="gamb_colu_arab",
                                site_class="CDS_DEG_4")

# %%
pop_list = ['gambiae_2004', 'arabiensis_2014', 'arabiensis_2015', 'arabiensis_2016',
            'coluzzii_2012', 'coluzzii_2014', 'coluzzii_2015', 'coluzzii_2016', 'coluzzii_2017',
            'gambiae_2012', 'gambiae_2014', 'gambiae_2015', 'gambiae_2016', 'gambiae_2017']
taxon_list = ['An. gambiae', 'An. arabiensis', 'An. arabiensis', 'An. arabiensis',
              'An. coluzzii', 'An. coluzzii', 'An. coluzzii', 'An. coluzzii', 'An. coluzzii',
              'An. gambiae', 'An. gambiae', 'An. gambiae', 'An. gambiae', 'An. gambiae']

stats_div_2R = div_stats_2R.copy()
stats_div_2R.insert(1, 'populations', pop_list)
stats_div_2R.insert(23, 'taxons', taxon_list)
#stats_div_2R

# %%
fig1_2R = px.bar(data_frame=stats_div_2R.iloc[1:,],
       x="populations",
       y="theta_pi_estimate",
       error_y="theta_pi_ci_err",
       title="2R - Nucleotide diversity",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig1_2R.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2R.update_yaxes(range=[0, 0.025],showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2R.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig1_2R.update_layout(yaxis_title=r'$\theta_{\pi}$', font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="be537ca3-5051-4365-be5c-8af9667cb0c1" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be537ca3-5051-4365-be5c-8af9667cb0c1")) {                    Plotly.newPlot(                        "be537ca3-5051-4365-be5c-8af9667cb0c1",                        [{"alignmentgroup":"True","error_y":{"array":[0.0008565341812516033,0.0007963126711391121,0.0008540665241719421]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.009726294225145107,0.009855158996286431,0.010927570181378242],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0011085571089394916,0.001081795757880637,0.0011243821740478765,0.001093942712640311,0.0010991276392570877]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.0170831108950433,0.016904575553253358,0.017166707004818482,0.016830810680096404,0.017041887328579027],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.00124434581516366,0.001206295902928239,0.001196697933881127,0.0012085345753488775,0.0012119759519546528]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.01906649012311914,0.018763326668347527,0.01872641253875385,0.018553685271540162,0.018545305777496433],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[ ...

# %%
fig2_2R = px.bar(data_frame=stats_div_2R.iloc[1:,],
       x="populations",
       y="theta_w_estimate",
       error_y="theta_w_ci_err",
       title="2R - Watterson estimator",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig2_2R.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_2R.update_yaxes(range=[0, 0.04], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_2R.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig2_2R.update_layout(yaxis_title=r'$\theta$', font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d1fc6869-eb6d-4159-9734-bffd741598fc" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1fc6869-eb6d-4159-9734-bffd741598fc")) {                    Plotly.newPlot(                        "d1fc6869-eb6d-4159-9734-bffd741598fc",                        [{"alignmentgroup":"True","error_y":{"array":[0.0009658232472420674,0.0008650004111595206,0.000998961513782487]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.01095916441385145,0.011437971919429945,0.013593532809662658],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0015282914158794559,0.00146916067204073,0.001530257045807721,0.0014927986974950737,0.0015295277647604385]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.02340704557376557,0.02324942106532364,0.023635137483426712,0.023039873383650673,0.02357579639728546],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.002155977968140304,0.002048468857564455,0.001980079479876336,0.0020164601024748137,0.0020141803583243745]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.02882339238508671,0.02775302970701461,0.028014129914239547,0.027436668221990264,0.027106954902150773],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"# ...

# %%
fig3_2R = px.bar(data_frame=stats_div_2R.iloc[1:,],
       x="populations",
       y="tajima_d_estimate",
       error_y="tajima_d_ci_err",
       title="2R - Tajima's D",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig3_2R.update_xaxes(tickangle= -35,showline=True, linewidth=0.5, linecolor='black', ticks="outside", side='top')
fig3_2R.update_yaxes(range=[-2, 0], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig3_2R.update_layout(showlegend=False, yaxis=dict(showgrid=False), xaxis_title=' ', font_color='black')
fig3_2R.update_layout(title={'text':"2R - Tajima's D", 'y':0.1, 'x':0.8})

# %% [markdown]
# # Diversity stats in the 2L chrom

# %%
div_stats_2L = ag3.diversity_stats(sample_query="country == 'Burkina Faso'",
                                cohorts="admin2_year",
                                cohort_size=10,
                                region="2L",
                                site_mask="gamb_colu_arab",
                                site_class="CDS_DEG_4")

# %%
stats_div_2L = div_stats_2L.copy()
stats_div_2L.insert(1, 'populations', pop_list)
stats_div_2L.insert(23, 'taxons', taxon_list)
#stats_div_2L

# %%
fig1_2L = px.bar(data_frame=stats_div_2L.iloc[1:,],
       x="populations",
       y="theta_pi_estimate",
       error_y="theta_pi_ci_err",
       title="2L - Nucleotide diversity",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig1_2L.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2L.update_yaxes(range=[0, 0.025], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2L.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig1_2L.update_layout(yaxis_title=r'$\theta_{\pi}$', font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a55869a3-0722-44f5-a591-a7eaf3a50317" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a55869a3-0722-44f5-a591-a7eaf3a50317")) {                    Plotly.newPlot(                        "a55869a3-0722-44f5-a591-a7eaf3a50317",                        [{"alignmentgroup":"True","error_y":{"array":[0.0010099500254517062,0.0010075722729047064,0.001021237146048415]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.009904969271984997,0.010040886888452996,0.010717663642554798],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.001705470681300281,0.001605361697045734,0.001662587652202105,0.0016437915453406894,0.0016260443430274173]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.01935456944969022,0.01878416585680197,0.019387456468255113,0.01933360125284087,0.018740596950786597],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0017595392113357207,0.001712998372723012,0.0017540985839000914,0.0016960616729475894,0.0017656058058928075]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.020632205999237468,0.020323996680884686,0.020705957363864755,0.019925366666481807,0.020002406744002412],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"] ...

# %%
fig2_2L = px.bar(data_frame=stats_div_2L.iloc[1:,],
       x="populations",
       y="theta_w_estimate",
       error_y="theta_w_ci_err",
       title="2L - Watterson estimator",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig2_2L.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_2L.update_yaxes(range=[0, 0.04], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_2L.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig2_2L.update_layout(yaxis_title=r'$\theta$' , font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="82465ff2-e52c-4503-ae61-e76eaaa99cdb" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82465ff2-e52c-4503-ae61-e76eaaa99cdb")) {                    Plotly.newPlot(                        "82465ff2-e52c-4503-ae61-e76eaaa99cdb",                        [{"alignmentgroup":"True","error_y":{"array":[0.0011441016746933457,0.0011393507183760697,0.001160911464278935]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.01129549567423338,0.01180144077864973,0.013389792807232187],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.002370883435927638,0.0021948276205493084,0.0022460119916896757,0.0022385047103995756,0.0022829858002968123]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.028293969060528258,0.02691223593911239,0.02827079223800686,0.028189919921122804,0.026885114125522438],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.00262987337939778,0.0024624437652110394,0.0025377094699821703,0.0024643221274327607,0.0025319469731067104]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.03070090673563304,0.03000658830774064,0.03038481432634467,0.029678660931317102,0.029133759034039086],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %%
fig3_2L = px.bar(data_frame=stats_div_2L.iloc[1:,],
       x="populations",
       y="tajima_d_estimate",
       error_y="tajima_d_ci_err",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig3_2L.update_xaxes(tickangle= -35,showline=True, linewidth=0.5, linecolor='black', ticks="outside", side='top')
fig3_2L.update_yaxes(range=[-2, 0], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig3_2L.update_layout(showlegend=False, yaxis=dict(showgrid=False), xaxis_title=' ', font_color='black')
fig3_2L.update_layout(title={'text':"2L - Tajima's D", 'y':0.1, 'x':0.8})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6adbe0df-fd20-47b8-b3d3-636b7eb6f44f" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6adbe0df-fd20-47b8-b3d3-636b7eb6f44f")) {                    Plotly.newPlot(                        "6adbe0df-fd20-47b8-b3d3-636b7eb6f44f",                        [{"alignmentgroup":"True","error_y":{"array":[0.10060326360043095,0.09875785108612119,0.08922683779538493]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[-0.5168612008045969,-0.6262594763163936,-0.8376715906623758],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.05227906380404765,0.05613577130100603,0.05576791475451032,0.054296113124443005,0.0539867593017497]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[-1.3262962574492172,-1.2678473993773733,-1.3190346221775389,-1.318804846238474,-1.2717239551137463],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.05544653209395312,0.050931930141657575,0.05093781188962134,0.049136173277118625,0.05263434563644339]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[-1.3768099391280069,-1.3546038001148437,-1.3372410210545882,-1.379571968192739,-1.3157707942163126],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatm ...

# %% [markdown]
# # Diversity stats in the 3L chrom

# %%
div_stats_3L = ag3.diversity_stats(sample_query="country == 'Burkina Faso'",
                                   cohorts="admin2_year",
                                   cohort_size=10,
                                   region="3L",
                                   site_mask="gamb_colu_arab",
                                   site_class="CDS_DEG_4")

# %%
stats_div_3L = div_stats_3L.copy()
stats_div_3L.insert(1, 'populations', pop_list)
stats_div_3L.insert(23, 'taxons', taxon_list)
#stats_div_3L

# %%
fig1_3L = px.bar(data_frame=stats_div_3L.iloc[1:,],
       x="populations",
       y="theta_pi_estimate",
       error_y="theta_pi_ci_err",
       title="3L - Nucleotide diversity",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig1_3L.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_3L.update_yaxes(range=[0, 0.025], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_3L.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig1_3L.update_layout(yaxis_title=r'$\theta_{\pi}$' , font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0247d862-22ed-4996-95db-db7479d06204" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0247d862-22ed-4996-95db-db7479d06204")) {                    Plotly.newPlot(                        "0247d862-22ed-4996-95db-db7479d06204",                        [{"alignmentgroup":"True","error_y":{"array":[0.0011153178156216503,0.001145604035431262,0.0011075151616774439]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.009648182343412026,0.010030941955862006,0.010527905132856827],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.00211959106014613,0.0021004918379343603,0.002086805423583017,0.002136766918333873,0.002117933486078614]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.017721205399853494,0.017698602582933185,0.017684797505865695,0.017689894504699655,0.017691187633091788],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0020892099718939263,0.0020238530508085973,0.0020821320551854387,0.0020697059312257873,0.0020714981159982407]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.018173467187178806,0.017990063029734434,0.017794352684570993,0.017719763400458766,0.017710887399218958],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26 ...

# %%
fig2_3L = px.bar(data_frame=stats_div_3L.iloc[1:,],
       x="populations",
       y="theta_w_estimate",
       error_y="theta_w_ci_err",
       title="3L - Watterson estimator",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig2_3L.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_3L.update_yaxes(range=[0, 0.04], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_3L.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig2_3L.update_layout(yaxis_title=r'$\theta$', font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b8a7c5a9-b030-4eba-b65c-6362c450d88d" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8a7c5a9-b030-4eba-b65c-6362c450d88d")) {                    Plotly.newPlot(                        "b8a7c5a9-b030-4eba-b65c-6362c450d88d",                        [{"alignmentgroup":"True","error_y":{"array":[0.0011821066376627826,0.0012617819844429183,0.0011722056539728869]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.011223088996162249,0.011974695828871583,0.013382684649096803],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0030431443152712343,0.0029762497496692666,0.002953264640024727,0.003024862576115338,0.0030244826648328973]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.025177808886962076,0.025041091535970464,0.0250472132205809,0.024948585807666807,0.02501388459275717],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0031232571025722952,0.0029647423656088646,0.003101740060118236,0.00312974618908359,0.003144347705287967]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.026905484321425678,0.026328686137640868,0.025945060296758568,0.02580630184028679,0.025488655515616306],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %%
fig3_3L = px.bar(data_frame=stats_div_3L.iloc[1:,],
       x="populations",
       y="tajima_d_estimate",
       error_y="tajima_d_ci_err",
       title="3L - Tajima's D",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig3_3L.update_xaxes(tickangle= -35,showline=True, linewidth=0.5, linecolor='black', ticks="outside", side='top')
fig3_3L.update_yaxes(range=[-2, 0], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig3_3L.update_layout(showlegend=False, yaxis=dict(showgrid=False), xaxis_title=' ', font_color='black')
fig3_3L.update_layout(title={'text':"3L - Tajima's D", 'y':0.1, 'x':0.8})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f8eaa19c-5393-402e-9556-913784ccd64f" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8eaa19c-5393-402e-9556-913784ccd64f")) {                    Plotly.newPlot(                        "f8eaa19c-5393-402e-9556-913784ccd64f",                        [{"alignmentgroup":"True","error_y":{"array":[0.11512872612709385,0.09422288944325295,0.10513167217778135]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[-0.5889421812110444,-0.6812811207379768,-0.8952489990872642],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.059354051477239475,0.0578146756842626,0.06092485284003244,0.06282317878023715,0.06163938124732544]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[-1.2433275736374014,-1.2309576477585817,-1.2339945907091177,-1.22143475387142,-1.229003549979481],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.06656507305393614,0.06558812922619713,0.06541135491587455,0.06879261138229771,0.07367125338549751]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[-1.3624994056508057,-1.3295986228402636,-1.318905814647241,-1.3156071117401005,-1.2811992508225902],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl ...

# %% [markdown]
# # Diversity stats in the 3R chrom

# %%
div_stats_3R = ag3.diversity_stats(sample_query="country == 'Burkina Faso'",
                                   cohorts="admin2_year",
                                   cohort_size=10,
                                   region="3R",
                                   site_mask="gamb_colu_arab",
                                   site_class="CDS_DEG_4")

# %%
stats_div_3R = div_stats_3R.copy()
stats_div_3R.insert(1, 'populations', pop_list)
stats_div_3R.insert(23, 'taxons', taxon_list)
#stats_div_3R

# %%
fig1_3R = px.bar(data_frame=stats_div_3R.iloc[1:,],
       x="populations",
       y="theta_pi_estimate",
       error_y="theta_pi_ci_err",
       title="3R - Nucleotide diversity",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig1_3R.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_3R.update_yaxes(range=[0, 0.025], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_3R.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig1_3R.update_layout(yaxis_title=r'$\theta_{\pi}$',  font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1752dbf7-547a-4345-b004-cd0e4953d4d3" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1752dbf7-547a-4345-b004-cd0e4953d4d3")) {                    Plotly.newPlot(                        "1752dbf7-547a-4345-b004-cd0e4953d4d3",                        [{"alignmentgroup":"True","error_y":{"array":[0.0015359683869620843,0.0015675900993711868,0.001464523685755114]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.012730983371462196,0.01291775460116532,0.012944162548902438],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0017231071637473945,0.0017076039015280512,0.001693918911065471,0.0017157927443843513,0.0016940481011984791]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.020039653144492565,0.019982293268541187,0.019909298421712077,0.01989575520985113,0.01988383180377133],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.001765852576645781,0.0017085381722065204,0.0017248302343687797,0.00175448780610098,0.0017272642935700503]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.020524938797275218,0.020283452046607156,0.02034003630882908,0.020259722931459903,0.02022984305937333],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[ ...

# %%
fig2_3R = px.bar(data_frame=stats_div_3R.iloc[1:,],
       x="populations",
       y="theta_w_estimate",
       error_y="theta_w_ci_err",
       title="3R - Watterson estimator",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig2_3R.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_3R.update_yaxes(range=[0, 0.04], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_3R.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig2_3R.update_layout(yaxis_title=r'$\theta$',  font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="557cfd3b-8068-4d47-aaff-c16451320037" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("557cfd3b-8068-4d47-aaff-c16451320037")) {                    Plotly.newPlot(                        "557cfd3b-8068-4d47-aaff-c16451320037",                        [{"alignmentgroup":"True","error_y":{"array":[0.0016727958241228636,0.0016581657153338129,0.0015296873711397063]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.01441215785317863,0.01461574228770989,0.015515857689709494],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.002532050373404575,0.0024841801088661118,0.0024379625600735107,0.0024850666116603766,0.0024706728066479903]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.028634303104711573,0.028649504202257627,0.028520838765279066,0.028435061807294743,0.02843560481708223],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.002743247181328067,0.0026185908959602505,0.0026672170210681207,0.0027476544476957433,0.002632536107739449]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.03048122275032582,0.029850925094427216,0.029936701581817587,0.029605537494587497,0.029558305760833452],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[ ...

# %%
fig3_3R = px.bar(data_frame=stats_div_3R.iloc[1:,],
       x="populations",
       y="tajima_d_estimate",
       error_y="tajima_d_ci_err",
       title="3R - Tajima's D",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig3_3R.update_xaxes(tickangle= -35,showline=True, linewidth=0.5, linecolor='black', ticks="outside", side='top')
fig3_3R.update_yaxes(range=[-2, 0],showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig3_3R.update_layout(showlegend=False, yaxis=dict(showgrid=False), xaxis_title=' ',  font_color='black')
fig3_3R.update_layout(title={'text':"3R - Tajima's D", 'y':0.1, 'x':0.8})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f8d77ccd-84cb-4192-b5b8-5c41f38215c0" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8d77ccd-84cb-4192-b5b8-5c41f38215c0")) {                    Plotly.newPlot(                        "f8d77ccd-84cb-4192-b5b8-5c41f38215c0",                        [{"alignmentgroup":"True","error_y":{"array":[0.09701472848221916,0.10250618072456122,0.1062995153471437]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[-0.4896432820207258,-0.4875678943303645,-0.6955509959206523],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.058204020004145526,0.05558019878155265,0.05330206449025374,0.054424878742876326,0.055105511276913426]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[-1.2601064526276238,-1.2700467970564604,-1.267565095082501,-1.2607385383252112,-1.2625643767427943],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.06100022340861627,0.05700030580920452,0.05796804446181151,0.06129932026580401,0.05489749575159451]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[-1.3713158263982652,-1.3455755887771335,-1.3458289446787584,-1.3253512061839305,-1.3249519051617062],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heat ...

# %% [markdown]
# #Diversity stats in the X chrom

# %%
div_stats_X = ag3.diversity_stats(sample_query="country == 'Burkina Faso'",
                                   cohorts="admin2_year",
                                   cohort_size=10,
                                   region="X",
                                   site_mask="gamb_colu_arab",
                                   site_class="CDS_DEG_4")

# %%
stats_div_X = div_stats_X.copy()
stats_div_X.insert(1, 'populations', pop_list)
stats_div_X.insert(23, 'taxons', taxon_list)
#stats_div_X

# %%
fig1_X = px.bar(data_frame=stats_div_X.iloc[1:,],
       x="populations",
       y="theta_pi_estimate",
       error_y="theta_pi_ci_err",
       title="X - Nucleotide diversity",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig1_X.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_X.update_yaxes(range=[0, 0.025], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_X.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig1_X.update_layout(yaxis_title=r'$\theta_{\pi}$',  font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ca70dc39-4cef-4623-8cdb-d3be44981c47" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca70dc39-4cef-4623-8cdb-d3be44981c47")) {                    Plotly.newPlot(                        "ca70dc39-4cef-4623-8cdb-d3be44981c47",                        [{"alignmentgroup":"True","error_y":{"array":[0.0003713649366718349,0.0003887870103971008,0.00039918503627721434]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.0038260425529705014,0.004383359683075837,0.004245001601490111],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0008018596140414513,0.0007960472096898874,0.0007765579675810457,0.0007939602626168263,0.000753296309944707]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.007418929003641352,0.007904090321701897,0.008128612389691483,0.0072962159459717115,0.007356691541837249],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0007706575138934202,0.0007344650195771662,0.000758184154540692,0.000723326677672546,0.0007476691331245397]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.007967651477406237,0.007856042790440347,0.007987965469842852,0.007967728341591382,0.00705500024920922],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#f ...

# %%
fig2_X = px.bar(data_frame=stats_div_X.iloc[1:,],
       x="populations",
       y="theta_w_estimate",
       error_y="theta_w_ci_err",
       title="X - Watterson estimator",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig2_X.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_X.update_yaxes(range=[0, 0.04], showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig2_X.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig2_X.update_layout(yaxis_title=r'$\theta$',  font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="917d739d-1942-41fb-85ad-cdfe7aefeba9" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("917d739d-1942-41fb-85ad-cdfe7aefeba9")) {                    Plotly.newPlot(                        "917d739d-1942-41fb-85ad-cdfe7aefeba9",                        [{"alignmentgroup":"True","error_y":{"array":[0.0004241480336898021,0.0004908937240983984,0.0005077787284794635]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.005443361018304161,0.006873683754751691,0.00682779801540072],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0014589925180504752,0.0011928174033945583,0.0012090903751336788,0.00126828860905507,0.001052378000084357]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.01334881708771345,0.013685749516661325,0.014360925395680055,0.012537295011766689,0.011319357697457531],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0012374874667991597,0.0010790031036244556,0.0011112054542483263,0.0010481882393658065,0.0012977943313011594]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_w_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.014198358776266245,0.013183629081137767,0.01358611191121393,0.013052527623792968,0.012572692582122624],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"], ...

# %%
fig3_X = px.bar(data_frame=stats_div_X.iloc[1:,],
       x="populations",
       y="tajima_d_estimate",
       error_y="tajima_d_ci_err",
       title="X - Tajima's D",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white",
       )
fig3_X.update_xaxes(tickangle= -35,showline=True, linewidth=0.5, linecolor='black', ticks="outside", side='top')
fig3_X.update_yaxes(range=[-2, 0],showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig3_X.update_layout(showlegend=False, yaxis=dict(showgrid=False), xaxis_title=' ',  font_color='black')
fig3_X.update_layout(title={'text':"X - Tajima's D", 'y':0.1, 'x':0.8})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ae5e8efc-4f5a-49e3-89dd-d1d55c965f17" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae5e8efc-4f5a-49e3-89dd-d1d55c965f17")) {                    Plotly.newPlot(                        "ae5e8efc-4f5a-49e3-89dd-d1d55c965f17",                        [{"alignmentgroup":"True","error_y":{"array":[0.1750372382299777,0.13016498038017743,0.13678467460454527]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[-1.2473044904557813,-1.5208796489232093,-1.587942492977629],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.08967377438025308,0.0926110913102456,0.08533720348454435,0.0946691000486913,0.09519531751657001]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[-1.8649757653951278,-1.7733789300553962,-1.8217624229410379,-1.7549042825818584,-1.4695621592484982],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.07852948924098216,0.08881888109284045,0.09301994687606013,0.08718034068512155,0.10106383649475131]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>tajima_d_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[-1.8421550834832165,-1.6963595638443232,-1.7296954655362322,-1.6353240353687557,-1.8424290302621873],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl ...

# %% [markdown]
# # Save diversity stats

# %%
# chrom 2
#stats_div_2R.to_csv('drive/MyDrive/Genomic/diversity_stats/2R_yty_div_sats.csv')
#stats_div_2L.to_csv('drive/MyDrive/Genomic/diversity_stats/2L_yty_div_sats.csv')

# chrom 3
#stats_div_3R.to_csv('drive/MyDrive/Genomic/diversity_stats/3R_yty_div_sats.csv')
#stats_div_3L.to_csv('drive/MyDrive/Genomic/diversity_stats/3L_yty_div_sats.csv')

# chrom X
#stats_div_X.to_csv('drive/MyDrive/Genomic/diversity_stats/X_yty_div_sats.csv')

# %% [markdown]
# # Load data

# %%
# additionnal plotting setup
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
## data - chrom 2
data_2R = pd.read_csv('drive/MyDrive/Genomic/diversity_stats/2R_yty_div_sats.csv')
data_2L = pd.read_csv('drive/MyDrive/Genomic/diversity_stats/2L_yty_div_sats.csv')

## data - chrom 3
data_3R = pd.read_csv('drive/MyDrive/Genomic/diversity_stats/3R_yty_div_sats.csv')
data_3L = pd.read_csv('drive/MyDrive/Genomic/diversity_stats/3L_yty_div_sats.csv')

## data - chrom X
data_X = pd.read_csv('drive/MyDrive/Genomic/diversity_stats/X_yty_div_sats.csv')

# %%
fig1_2R = px.bar(data_frame=data_2R.iloc[1:,],
       x="populations",
       y="theta_pi_estimate",
       error_y="theta_pi_ci_err",
       title="2R - Nucleotide diversity",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig1_2R.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2R.update_yaxes(range=[0, 0.025],showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2R.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig1_2R.update_layout(yaxis_title=r'$\theta_{\pi}$', font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e4a0ebc5-c82a-40ad-be2f-48a8590ed9b6" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4a0ebc5-c82a-40ad-be2f-48a8590ed9b6")) {                    Plotly.newPlot(                        "e4a0ebc5-c82a-40ad-be2f-48a8590ed9b6",                        [{"alignmentgroup":"True","error_y":{"array":[0.0008565341812516,0.0007963126711391,0.0008540665241719]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.0097262942251451,0.0098551589962864,0.0109275701813782],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0011085571089394,0.0010817957578806,0.0011243821740478,0.0010939427126403,0.001099127639257]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.0170831108950433,0.0169045755532533,0.0171667070048184,0.0168308106800964,0.017041887328579],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0012443458151636,0.0012062959029282,0.0011966979338811,0.0012085345753488,0.0012119759519546]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.0190664901231191,0.0187633266683475,0.0187264125387538,0.0185536852715401,0.0185453057774964],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorba ...

# %%
fig1_2L = px.bar(data_frame=data_2L.iloc[1:,],
       x="populations",
       y="theta_pi_estimate",
       error_y="theta_pi_ci_err",
       title="2R - Nucleotide diversity",
       color='taxons',
       height=450,
       width=600,
       template="plotly_white"
       )
fig1_2L.update_xaxes(tickangle= -35, showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2L.update_yaxes(range=[0, 0.025],showline=True, linewidth=0.5, linecolor='black', ticks="outside")
fig1_2L.update_layout(showlegend=False, xaxis=dict(showgrid=False),yaxis=dict(showgrid=False))
fig1_2L.update_layout(yaxis_title=r'$\theta_{\pi}$', font_color='black')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f128f274-e0e5-4b03-84d1-40021759dc57" class="plotly-graph-div" style="height:450px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f128f274-e0e5-4b03-84d1-40021759dc57")) {                    Plotly.newPlot(                        "f128f274-e0e5-4b03-84d1-40021759dc57",                        [{"alignmentgroup":"True","error_y":{"array":[0.0010099500254517,0.0010075722729047,0.0010212371460484]},"hovertemplate":"taxons=An. arabiensis<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. arabiensis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"An. arabiensis","offsetgroup":"An. arabiensis","orientation":"v","showlegend":true,"textposition":"auto","x":["arabiensis_2014","arabiensis_2015","arabiensis_2016"],"xaxis":"x","y":[0.0099049692719849,0.0100408868884529,0.0107176636425547],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0017054706813002,0.0016053616970457,0.0016625876522021,0.0016437915453406,0.0016260443430274]},"hovertemplate":"taxons=An. coluzzii<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. coluzzii","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"An. coluzzii","offsetgroup":"An. coluzzii","orientation":"v","showlegend":true,"textposition":"auto","x":["coluzzii_2012","coluzzii_2014","coluzzii_2015","coluzzii_2016","coluzzii_2017"],"xaxis":"x","y":[0.0193545694496902,0.0187841658568019,0.0193874564682551,0.0193336012528408,0.0187405969507865],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","error_y":{"array":[0.0017595392113357,0.001712998372723,0.0017540985839,0.0016960616729475,0.0017656058058928]},"hovertemplate":"taxons=An. gambiae<br>populations=%{x}<br>theta_pi_estimate=%{y}<extra></extra>","legendgroup":"An. gambiae","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"An. gambiae","offsetgroup":"An. gambiae","orientation":"v","showlegend":true,"textposition":"auto","x":["gambiae_2012","gambiae_2014","gambiae_2015","gambiae_2016","gambiae_2017"],"xaxis":"x","y":[0.0206322059992374,0.0203239966808846,0.0207059573638647,0.0199253666664818,0.0200024067440024],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar" ...
